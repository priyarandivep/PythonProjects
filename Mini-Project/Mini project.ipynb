# %%
while True:

    print("Main Menu")
    print("-------------------------")
    print("1.  List\n2.  Tuple\n3.  set\n4.  dictionary\n5.  Exit")
    print("-------------------------")
    ch=int(input("Enter your choice"))
    L=[1,2,"python"]
    t=(1,2,"python")
    s={1,2,3,4,5}
    d={1:2,3:4,5:6}
    
    if ch==1:
        while True:
            print('--------------------------------------')
            print("List Operations")
            print("---------------------------------------")
            print("1.  Def\n2.  add elements into the list\n3.  Deletion\n4.  Exit")
            print("---------------------------------------")

            ch1= int(input("enter your choice"))
        
        
            if ch1==1:
                print('-------------------')
                print('Definition of list')
                print('-------------------')
                print("Lists are used to store multiple items in a single variable.\nLists are created using square brackets\nList items are ordered, changeable, and allow duplicate values.")
                print('--------------------------------------------------------------------------------------------')
                continue
            elif ch1==2:
                 while True:
                    print('---------------------')
                    print("List:Addition Method")
                    print("----------------------")
                    print("1.Do you want to add single element\n2.Do you want to add multiple elements\n3.Do you want to add element at Specific index position\n4.Exit")
                
               
                    ch1_add=int(input('Enter your choice of addition'))
                    if ch1_add==1:
                        print('Adding Single element')
                        print(L)
                        L.append(int(input('Enter a number u want to add: ')))
                        print(L)
                        continue
                    elif ch1_add==2:
                        print('Adding multiple Element')
                        new_list=[]
                        n=int(input("Enter numbers of ele you want to add: "))
                        for i in range(0, n):
                            ele = input()
                            new_list.append(ele)
                        L.extend(new_list)
                        print(L)
                        continue

                    elif ch1_add==3:
                        print('Adding element at specifice index position')
                        i= int(input('Enter index number: '))
                        n= int(input('enter a number: '))
                        L.insert(i,n)
                        print(L)
                        continue
                    elif ch1_add==4:
                        print("-------------------------")
                        print('Your have selected exit button ')
                        print('--------------------------')
                        break
                        
                    else:
                        print("wrong Choice")
                        continue


            elif ch1==3:
                while True:
                    print("List: Deletion Method")
                    print("----------------")
                    print("1.Do you want to Delete element of the end\n2.Do you want to delete specific value from the list\n3.Do you want to delete element at specific index position\n4.Exit")
                    ch1_delete=int(input("Enter your choice"))

                
                    if ch1_delete==1:
                        print('Deleting element of the end')
                        print('Before deleting:',L)
                        L.pop()
                        print("After deletion:", L)
                        continue
                        
                    elif ch1_delete==2:
                        print('Deleting element of specific value')
                        print('Before deleting:',L)
                        A= input('enter a value which you want to delete')
                        if A in L:
                            L.remove(A)
                            print("After deletion:", L)
                        else:
                                print("Enter correct value")
                        continue
                        
                    elif ch1_delete==3:
                        print('Deleting element of specific index position')
                        print('Before deleting:',L)
                        A= int(input("Enter index position"))
                        del L[A]
                        print("After deletion", L)
                        
                    elif ch1_delete==4:
                        print('You have selected exit')
                        break
                        
                    else:
                        Print("Wrong choice")
                        continue
            elif ch1==4:
                print("---------------------------------")
                print('You have selected the exit button')
                print("---------------------------------")
                break
            
            else:
                print('Wrong Choice')
                continue



    elif ch==2:
        while True:
            print("-------------------")
            print("Tuple Operations")
            print("-----------------")
            print("1.Def\n2.add elements into tuple\n3.Deletion\n4.Exit")
            ch2=int(input('Enter your choice'))

        
            if ch2==1:
                print("-----------------")
                print("Definition of Tuple")
                print('------------------')
                print("Tuples are used to store multiple items in a single variable.")
                print('A tuple is a collection which is ordered and unchangeable.')
                print('A tuple is a collection which is ordered and unchangeable.')
                print('------------------')
                continue
            elif ch2==2:
                while True:
                    print('Tuple: addition Methods')
                    print("---------------")
                    print("1.Do you want to add single element\n2.Do you want to add multiple elements\n3.Do you want to add element at Specific index position\n4.Exit")

                    ch2_add=int(input('Enter a number'))


                    if ch2_add==1:
                        print('Adding single element into tuple')
                        print('tuple before adding element:',t)
                        t=list(t)
                        t.append(int(input('Enter a number u want to add: ')))
                        t=tuple(t)
                        print('Tuple after adding element:',t)
                        continue
                    elif ch2_add==2:
                        print('Adding multiple elements into tuple')
                        print('Tuple before adding element:',t)
                        t=list(t)
                        new_list=[]
                        n=int(input("Enter numbers of ele you want to add: "))
                        for i in range(0, n):
                            ele = input()
                            new_list.append(ele)
                        t.extend(new_list)
                        t=tuple(t)
                        print('Tuple after adding element',t)
                        continue
                    elif ch2_add==3:
                        print('Adding element at specific index position')
                        print('Tuple before adding element',t)
                        t=list(t)
                        i= int(input('Enter index number: '))
                        n= int(input('enter a number: '))
                        t.insert(i,n)
                        print('Tuple after adding element',t)
                        continue
                    elif ch2_add==4:
                        print("---------------------------------")
                        print('you have selected the exit button')
                        print("---------------------------------")
                        break
                    else:
                        print('Wrong Choice')
                        continue
                        


            elif ch2==3:
                while True:
                    print('-----------------')
                    print('Tuple: Deletion Methods')
                    print('-----------------')
                    print("1.Do you want to Delete element of the end\n2.Do you want to delete specific value from the list\n3.Do you want to delete element at specific index position\n4.Exit")

                    ch2_delete=int(input("Enter a number"))


                    if ch2_delete==1:
                        print('deleting element at the end')
                        print('Before deletion ',t)
                        t=list(t)
                        t.pop()
                        t=tuple(t)
                        print("After deletion:", t)
                        continue
                    elif ch2_delete==2:
                        Print('deleting element of specific value')
                        print('Before deletion',t)
                        t=list(t)
                        A= input('enter a value which you want to delete')
                        if A in t:
                            t.remove(A)
                            t=tuple(t)
                            print("After deletion:", t)
                        else:
                            print("Enter correct value")
                            continue
                    elif ch2_delete==3:
                        print('deleting element of specific index position')
                        print('Before deletion',t)
                        t=list(t)

                        A= int(input("Enter index position"))
                        del t[A]
                        t=tuple(t)
                        print("After deletion", t)
                        continue
                    elif ch2_delete==4:
                        print("---------------------------------")
                        print('You have selected exit button')
                        print("---------------------------------")
                        break
                    
                    else:
                        print('Wrong Choice')
                        continue
            elif ch2==4:
                    print("---------------------------------")
                    print('You have selected the exit button')
                    print("---------------------------------")
                    break
            else:
                    print('Wrong choice ')
                    continue
        
    elif ch==3:
        while True:
            print("-------------------")
            print("Set Operations")
            print("-----------------")
            print("1.Def\n2.add elements into Set\n3.Deletion\n4.Exit")
            ch3=int(input('Enter your choice'))
            
            if ch3==1:
                print("-----------------")
                print("Definition of Set")
                print('------------------')
                print('A Set is an unordered collection data type that is iterable, mutable, and has no duplicate elements')
                print('Set are represented by { }')
                print('---------------------------------------------------------------------------------------------------')
                continue
            elif ch3==2:
                while True:
                    print('set: addition Methods')
                    print("---------------")
                    print("1.Do you want to add single element\n2.Do you want to add multiple elements\n3.Exit")
                    
                    ch3_add=int(input('Enter your choice'))
                    
                    if ch3_add==1:
                        print('adding single element')
                        print('Set before adding element', s)
                        a= int(input('Enter a value u want to add into set'))
                        s.add(a)
                        print('Set after adding element', s)
                        continue
                    
                    elif ch3_add==2:
                        print('Adding multiple element')
                        print('set before adding element:', s)
                        new_list=[]
                        n=int(input("Enter numbers of ele you want to add: "))
                        for i in range(0, n):
                            ele = input()
                            new_list.append(ele)
                        s.update(new_list)
                        print('Set after adding multiple elements:',s)
                        continue
                    elif ch3_add==3:
                        print("---------------------------------")
                        print('You have selected exit button')
                        print("---------------------------------")
                        break
                    else:
                        print('Wrong choice')
                        continue
            elif ch3==3:
                while True:
                    print('-----------------')
                    print('Set: Deletion Methods')
                    print('-----------------')
                    print("1.Do you want to delete specific value from the set\n2.Do you want to delete all the elements from the set\n3.Exit")
                    ch3_delete=int(input('enter ur choice'))
                    
                    if ch3_delete==1:
                        print('Deleting specific value')
                        print(s)
                        s.remove(int(input('Enter element u want to remove from the above Set')))
                        print('Set after deletion:', s)
                        continue
                    elif ch3_delete==2:
                        print('deleting all the elements of set')
                        print(s)
                        s.clear()
                        print('set after deletion:',s)
                        continue
                    elif ch3_delete==3:
                        print('You have selected the exit button')
                        break
                    else:
                        print('Wrong Choice')
                        continue
            elif ch3==4:
                print("---------------------------------")
                print('You have selected the exit button')
                print("---------------------------------")
                break
            else:
                print('Wrong choice')
                continue
    
    elif ch==4:
        while True:
            print("-------------------")
            print("Dictionary Operations")
            print("-----------------")
            print("1.  Def\n2.  add elements into Set\n3.  Deletion\n4.Exit")
            ch4=int(input('Enter your choice:'))
            
            if ch4==1:
                print("-----------------")
                print("Definition of Dictionary")
                print('------------------')
                print("Dictionaries are Python's implementation of a data structure that is more generally known as")
                print("an associative array. A dictionary consists of a collection of key-value pairs.")
                print("Each key-value pair maps the key to its associated value.")
                print('--------------------------------------------------------------------------------------------------')
                continue
            
            elif ch4==2:
                while(True):
                    print("------------------------")
                    print("Dictionary: Addition methods")
                    print("------------------------")
                    print("1.Do you want update single element\n2.Do you want to add a new element with a key and value\n3.Do you want to add multiple new elements\n4.    Quit")
                    
                    ch4_add=int(input('Enter your choice'))
                    
                    if ch4_add==1:
                        print('Updating Existing element')
                        print('dictionary before adding element', d)
                        key = int(input("Enter the key to update: "))
                        value = int(input("Enter the new value: "))
                        if key in d:
                            # Update the value of the key
                            d[key] = value
                            print("Dictionary after updating value of the key",d)
                        else:
                            print("The key does not exist in the dictionary.")
                    elif ch4_add==2:
                        print('Adding new element')
                        print('dictionary before adding element', d)
                        key = int(input("Enter the key to add: "))
                        value = int(input("Enter the value to add: "))
                        if key in d:
                            print("The key already exists in the dictionary.")
                        else:
                            # Add the new element to the dictionary
                            d[key] = value
                            print("Dictionary after adding key and value",d)
                    elif ch4_add==3:
                        print('Adding multiple elements')
                        new_elements = int(input("Enter the number of elements to add: "))
                        # Using a loop, take input from the user for each key and value of the new elements they want to add
                        for i in range(new_elements):
                            key = int(input("Enter the key to add: "))
                            value = int(input("Enter the value to add: "))

                            # Check if the key already exists in the dictionary or not
                            if key in d:
                                print("The key already exists in the dictionary.")
                            else:
                                # Add the new element to the dictionary
                                d[key] = value
                                print("The new element has been added to the dictionary.", d)
                    elif ch4_add==4:
                        print("---------------------------------")
                        print('You have selected the exit button')
                        print("---------------------------------")
                        break
                    else:
                        print('Wrong Choice')
                        
            elif ch4==3:
                while True:
                    print('-----------------')
                    print('Dictionary: Deletion Methods')
                    print('-----------------')
                    pprint("1.  Deletion of element(s)\n2.   Exit")
                    ch4_delete=int(input('enter ur choice'))
                    if ch4_delete==1:
                        print('deleting element')
                        # Take input from the user for the key(s) of the element(s) they want to delete
                        keys_to_delete = input("Enter the key(s) to delete (separated by comma): ")

                        # Split the input string into a list of keys
                        keys_to_delete = keys_to_delete.split(',')

                        # Using a loop, check if each key exists in the dictionary or not
                        for key in keys_to_delete:
                            if key in d:
                                # Delete the element from the dictionary
                                del d[key]
                                print("The element with key",key,"has been deleted from the dictionary.")
                            else:
                                print("The key",key,"does not exist in the dictionary.")
                    elif ch4_delete==2:
                        print("---------------------------------")
                        print("You have selected the exit button")
                        print("---------------------------------")
                        break
                    else:
                        print("Wrong choice!!!!")
                        
            elif ch4==4:
                print("---------------------------------")
                print("You have selected the exit button")
                print("---------------------------------")
                break
            else:
                print("Wrong choice!!!!")
                
                
    elif ch==5:
        print("---------------------------------")
        print('You have selected the exit button')
        print("---------------------------------")
        break
    else:
        print('Wrong Choice')
# Out:
# Main Menu
# -------------------------
# 1.  List
# 2.  Tuple
# 3.  set
# 4.  dictionary
# 5.  Exit
# -------------------------
# Enter your choice4
# -------------------
# Dictionary Operations
# -----------------
# 1.  Def
# 2.  add elements into Set
# 3.  Deletion
# 4.Exit
# Enter your choice:4
# ---------------------------------
# You have selected the exit button
# ---------------------------------
# Main Menu
# -------------------------
# 1.  List
# 2.  Tuple
# 3.  set
# 4.  dictionary
# 5.  Exit
# -------------------------
# Enter your choice4
# -------------------
# Dictionary Operations
# -----------------
# 1.  Def
# 2.  add elements into Set
# 3.  Deletion
# 4.Exit
# Enter your choice:4
# ---------------------------------
# You have selected the exit button
# ---------------------------------
# Main Menu
# -------------------------
# 1.  List
# 2.  Tuple
# 3.  set
# 4.  dictionary
# 5.  Exit
# -------------------------
